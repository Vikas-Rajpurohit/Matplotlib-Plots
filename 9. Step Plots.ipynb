# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5]
y = [3,4,2,1,5]

plt.step(x, y, marker='.', ms=10, mfc='g', label='growth')

plt.xlabel('x-axis')
plt.ylabel('y-axis')

plt.legend()
plt.grid()
plt.show()
