# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5]

area1 = [2,3,5,4,1]
area2 = [3,5,1,2,4]
area3 = [1,2,5,3,4]

l = ['A1','A2','A3']
plt.stackplot(x,area1,area2,area3,labels=l)

plt.legend(loc=2)
plt.show()
